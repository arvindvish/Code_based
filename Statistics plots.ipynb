# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
d = pd.read_csv("C:\\Users\\uttam singh\\OneDrive\\Desktop\\Sales_Details.csv")
d.head()
# Out:
#    Sr. No.     Project Unit Code           Customer Name    Floor  \
# 0        1  7th Avenue       101       Mr Surender Singh  FLOOR 1
# 1        2  7th Avenue       102         MR.VASEEM ZAIDI  FLOOR 1
# 2        3  7th Avenue       103  Mr. Saurabh Srivastava  FLOOR 1
# 3        4  7th Avenue       104    Mrs. Sonee Jakhanwal  FLOOR 1
# 4        5  7th Avenue       105         Mr. Ram Narayan  FLOOR 1
#
#   Booking Date   Level3  Super Built-Up                           Broker Name  \
# 0   22-03-2018  BLOCK-A            1165  INVESTORS CLINIC INFRATECH PVT. LTD.
# 1   26-06-2018  BLOCK-A            1165                          GAUR CONNECT
# 2   15-03-2018  BLOCK-A            1165                SANG INFRATECH PVT LTD
# 3   30-03-2018  BLOCK-A            1165  INVESTORS CLINIC INFRATECH PVT. LTD.
# 4   27-07-2018  BLOCK-A            1165  INVESTORS CLINIC INFRATECH PVT. LTD.
#
#    Basic  Amount  Bill Amount  Received Amount  Onaccount Amount  \
# ...

# %%
print (d.shape )
# Out:
# (1786, 15)

# %%
print(d.columns)
# Out:
# Index(['Sr. No.', 'Project', 'Unit Code', 'Customer Name', 'Floor',
#        'Booking Date', 'Level3', 'Super Built-Up', 'Broker Name',
#        'Basic  Amount', 'Bill Amount', 'Received Amount', 'Onaccount Amount',
#        'Total Received', 'Balance'],
#       dtype='object')

# %%
d["Level3"].value_counts()
# Out:
# BLOCK-B    256
# BLOCK-I    256
# BLOCK-J    256
# BLOCK-C    255
# BLOCK-D    255
# BLOCK-A    254
# BLOCK-K    254
# Name: Level3, dtype: int64

# %%
d.plot(x= 'Bill Amount',y= 'Balance')
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(d, hue='Level3', size=4) \
    .map(plt.scatter, "'Level3'","Balance") \
    .add_legend();
plt.show();
# Out:
# C:\Users\uttam singh\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid");
sns.pairplot(d, hue="Level3", height=2);
plt.show();

# %%
d_Bill_Amount = d.loc[d["Level3"] =="Bill_Amount"];
d_Balance = d.loc[d["Level3"] =="Balance"];
plt.plot(d_Bill_Amount["PetalLengthM"],np.zeros_like(d_Bill_Amount["PetalLengthM"]),'0')
plt.plot(d_Balance["PetalLengthCm"],np.zeros_like(d_Balance["PetalLengthCm"]),'0')

plt.show()

# %%
sns.FacetGrid(d,Y="Level3"(str),height=1)\
    .map(sas.distplot,"Length").add_legend()
plt.show()
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\UTTAMS~1\AppData\Local\Temp/ipykernel_8076/2826183606.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   sns.FacetGrid(d,Y="Level3"(str),height=1)\
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\UTTAMS~1\AppData\Local\Temp/ipykernel_8076/2826183606.py in <module>
# ----> 1 sns.FacetGrid(d,Y="Level3"(str),height=1)\
#       2     .map(sas.distplot,"Length").add_legend()
#       3 plt.show()
#
# TypeError: 'str' object is not callable

# %%
counts, bin=edges = np.histogram(d_Balance['Petal_Lenght'], bins=10,density = True)
pdf = counts/(sum(counts))
print(pdf)
print(bin_edges)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Petal_Lenght'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print("Means:")
print(np.mean(d_Balance.ge))
# Out:
# Means:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\UTTAMS~1\AppData\Local\Temp/ipykernel_8076/2681850175.py in <module>
#       1 print("Means:")
# ----> 2 print(np.mean(d_Balance.get_loc))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_loc'

# %%
sns.boxplot(x='Level3',data=d)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\UTTAMS~1\AppData\Local\Temp/ipykernel_8076/219245385.py in <module>
# ----> 1 sns.boxplot(x='Level3',data=d)
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
#    2245                           width, dodge, fliersize, linewidth)
#
# ...
